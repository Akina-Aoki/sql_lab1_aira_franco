# %%
import duckdb
from pathlib import Path

duckdb_path = "18_pandas_duckdb/data/sakila.duckdb"
Path(duckdb_path).unlink(missing_ok=True)

with duckdb.connect(duckdb_path) as conn, open("18_pandas_duckdb/sql/load_sakila.sql") as ingest_script:
    conn.sql(ingest_script.read())

    description = conn.sql("DESC;").df()
    films = conn.sql("FROM film;").df()

films.head(3)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[2], line 7
#       4 duckdb_path = "18_pandas_duckdb/data/sakila.duckdb"
#       5 Path(duckdb_path).unlink(missing_ok=True)
# ----> 7 with duckdb.connect(duckdb_path) as conn, open("18_pandas_duckdb/sql/load_sakila.sql") as ingest_script:
#       8     conn.sql(ingest_script.read())
#      10     description = conn.sql("DESC;").df()
#
# Cell In[2], line 8
#       5 Path(duckdb_path).unlink(missing_ok=True)
#       7 with duckdb.connect(duckdb_path) as conn, open("18_pandas_duckdb/sql/load_sakila.sql") as ingest_script:
# ----> 8     conn.sql(ingest_script.read())
#      10     description = conn.sql("DESC;").df()
#      11     films = conn.sql("FROM film;").df()
#
# Error: Unable to open database "data/sqlite-sakila.db": unable to open database file

# %%
# look at the head() of the description dataframe
description.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # look at the head() of the description dataframe
# ----> 2 description.head()
#
# NameError: name 'description' is not defined
